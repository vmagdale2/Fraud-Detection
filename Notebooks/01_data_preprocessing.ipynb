# %% [markdown]
# # Clean & Process

# %% [markdown]
# ## Setup

# %%
# !pip install python-dotenv google-api-python-client

from google.colab import drive
drive.mount('/content/drive')

import os
from dotenv import load_dotenv
load_dotenv("/content/drive/MyDrive/Professional/Portfolio/Fraud Detection/.envs/.env_github")
github_pat = os.getenv("GITHUB_PAT")
print(f"✅ GITHUB_PAT loaded successfully")
if not github_pat:
    raise ValueError("❌ Error: 'GITHUB_PAT' is missing or invalid in your .env file.")

# !git clone https://{github_pat}@github.com/vmagdale2/Fraud-Detection.git

import sys
sys.path.append('/content/Fraud-Detection.git/')
# %cd /content/Fraud-Detection/
# !pwd
# !ls
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.11/dist-packages (2.164.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (2.38.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (2.24.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.69.2)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (5.29.4)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.26.1)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client) (3.2.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2025.1.31)
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.1.0
# Mounted at /content/drive
# ✅ GITHUB_PAT loaded successfully
# Cloning into 'Fraud-Detection'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 10 (delta 1), reused 5 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (10/10), 16.63 KiB | 3.33 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# /content/Fraud-Detection
# /content/Fraud-Detection
# Data  LICENSE  README.md

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = "/content/drive/MyDrive/Professional/Portfolio/Fraud Detection/Data/Variant II.csv/fifar_variant_II.csv"

try:
  df = pd.read_csv(file_path)
  print("DataFrame loaded successfully.")
except FileNotFoundError:
  print(f"Error: File not found at {file_path}")
except pd.errors.ParserError:
  print(f"Error: Unable to parse the CSV file at {file_path}. Check the file format.")
except Exception as e:
  print(f"An unexpected error occurred: {e}")
# Out:
# DataFrame loaded successfully.

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# # Exploration

# %%
df.shape
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 32 columns):
#  #   Column                            Non-Null Count    Dtype
# ---  ------                            --------------    -----
#  0   fraud_bool                        1000000 non-null  int64
#  1   income                            1000000 non-null  float64
#  2   name_email_similarity             1000000 non-null  float64
#  3   prev_address_months_count         1000000 non-null  int64
#  4   current_address_months_count      1000000 non-null  int64
#  5   customer_age                      1000000 non-null  int64
#  6   days_since_request                1000000 non-null  float64
#  7   intended_balcon_amount            1000000 non-null  float64
#  8   payment_type                      1000000 non-null  object
#  9   zip_count_4w                      1000000 non-null  int64
#  10  velocity_6h                       1000000 non-null  float64
#  11  velocity_24h                      1000000 non-null  float64
#  12  velocity_4w                       1000000 non-null  float64
#  13  bank_branch_count_8w              1000000 non-null  int64
#  14  date_of_birth_distinct_emails_4w  1000000 non-null  int64
#  15  employment_status                 1000000 non-null  object
#  16  credit_risk_score                 1000000 non-null  int64
#  17  email_is_free                     1000000 non-null  int64
#  18  housing_status                    1000000 non-null  object
#  19  phone_home_valid                  1000000 non-null  int64
#  20  phone_mobile_valid                1000000 non-null  int64
#  21  bank_months_count                 1000000 non-null  int64
#  22  has_other_cards                   1000000 non-null  int64
#  23  proposed_credit_limit             1000000 non-null  float64
#  24  foreign_request                   1000000 non-null  int64
#  25  source                            1000000 non-null  object
#  26  session_length_in_minutes         1000000 non-null  float64
#  27  device_os                         1000000 non-null  object
#  28  keep_alive_session                1000000 non-null  int64
#  29  device_distinct_emails_8w         1000000 non-null  int64
#  30  device_fraud_count                1000000 non-null  int64
#  31  month                             1000000 non-null  int64
# dtypes: float64(9), int64(18), object(5)
# memory usage: 244.1+ MB

# %%
df.head()
# Out:
#    fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 0           0   0.700                  0.062                         -1
# 1           0   0.900                  0.098                         -1
# 2           0   0.600                  0.117                         -1
# 3           0   0.300                  0.059                         10
# 4           0   0.100                  0.690                         -1
#
#    current_address_months_count  customer_age  days_since_request  \
# 0                            24            50               0.017
# 1                           310            50               0.019
# 2                           189            60               0.047
# 3                            40            60               0.008
# 4                           128            30               2.514
#
#    intended_balcon_amount payment_type  zip_count_4w  velocity_6h  \
# 0                  -0.872           AB          3430     8645.190
# 1                  -1.024           AB          3492     1610.761
# 2                  -1.206           AB          4621     8382.980
# 3                  -0.076           AA          1697    13872.725
# 4                  -1.108           AD          1431     7755.173
#
#    velocity_24h  velocity_4w  bank_branch_count_8w  \
# 0      5569.162     6258.579                   615
# 1      6214.332     6020.948                    12
# 2      6034.593     6772.412                     7
# 3      7594.434     5961.464                    29
# 4      5485.056     5993.340                    10
#
#    date_of_birth_distinct_emails_4w employment_status  credit_risk_score  \
# 0                                 5                CB                 55
# 1                                 7                CA                268
# 2                                 8                CB                 86
# 3                                14                CA                113
# 4                                10                CB                115
#
#    email_is_free housing_status  phone_home_valid  phone_mobile_valid  \
# 0              1             BC                 1                   1
# 1              1             BA                 0                   1
# 2              1             BC                 1                   1
# 3              1             BC                 0                   1
# 4              1             BC                 0                   1
#
#    bank_months_count  has_other_cards  proposed_credit_limit  foreign_request  \
# 0                 30                1                200.000                0
# 1                  5                1               1500.000                0
# 2                 30                0                200.000                0
# 3                  2                1                200.000                0
# 4                 30                0                200.000                0
#
#      source  session_length_in_minutes  device_os  keep_alive_session  \
# 0  INTERNET                      6.804      other                   0
# 1  INTERNET                      1.412  macintosh                   0
# 2  INTERNET                     14.489      other                   1
# 3  INTERNET                      6.152      linux                   1
# 4  INTERNET                      5.600      other                   0
#
#    device_distinct_emails_8w  device_fraud_count  month
# 0                          1                   0      0
# 1                          1                   0      0
# 2                          1                   0      0
# 3                          1                   0      0
# 4                          1                   0      0

# %%
df.describe()
# Out:
#        fraud_bool      income  name_email_similarity  \
# count 1000000.000 1000000.000            1000000.000
# mean        0.011       0.575                  0.489
# std         0.104       0.289                  0.291
# min         0.000       0.100                  0.000
# 25%         0.000       0.300                  0.215
# 50%         0.000       0.600                  0.490
# 75%         0.000       0.800                  0.754
# max         1.000       0.900                  1.000
#
#        prev_address_months_count  current_address_months_count  customer_age  \
# count                1000000.000                   1000000.000   1000000.000
# mean                      14.825                        99.381        41.304
# std                       43.231                        94.559        13.805
# min                       -1.000                        -1.000        10.000
# 25%                       -1.000                        26.000        30.000
# 50%                       -1.000                        64.000        50.000
# 75%                       -1.000                       154.000        50.000
# max                      399.000                       429.000        90.000
#
#        days_since_request  intended_balcon_amount  zip_count_4w  velocity_6h  \
# count         1000000.000             1000000.000   1000000.000  1000000.000
# mean                0.912                   8.639      1567.401     5685.095
# std                 4.987                  20.574      1009.619     3001.708
# min                 0.000                 -15.740         1.000     -174.110
# 25%                 0.007                  -1.178       901.000     3470.243
# 50%                 0.016                  -0.831      1236.000     5408.426
# 75%                 0.027                   0.079      1909.000     7653.990
# max                76.578                 112.703      6650.000    16801.340
#
#        velocity_24h  velocity_4w  bank_branch_count_8w  \
# count   1000000.000  1000000.000           1000000.000
# mean       4787.410     4860.388               202.464
# std        1470.369      916.809               474.134
# min        1322.325     2870.592                 0.000
# 25%        3628.562     4271.193                 1.000
# 50%        4765.968     4919.354                10.000
# 75%        5750.775     5489.469                32.000
# max        9539.357     7019.201              2377.000
#
#        date_of_birth_distinct_emails_4w  credit_risk_score  email_is_free  \
# count                       1000000.000        1000000.000    1000000.000
# mean                              7.951            137.458          0.523
# std                               4.961             72.199          0.499
# min                               0.000           -191.000          0.000
# 25%                               4.000             87.000          0.000
# 50%                               7.000            128.000          1.000
# 75%                              11.000            187.000          1.000
# max                              39.000            388.000          1.000
#
#        phone_home_valid  phone_mobile_valid  bank_months_count  \
# count       1000000.000         1000000.000        1000000.000
# mean              0.490               0.855             11.196
# std               0.500               0.352             12.109
# min               0.000               0.000             -1.000
# 25%               0.000               1.000              1.000
# 50%               0.000               1.000              6.000
# 75%               1.000               1.000             25.000
# max               1.000               1.000             32.000
#
#        has_other_cards  proposed_credit_limit  foreign_request  \
# count      1000000.000            1000000.000      1000000.000
# mean             0.244                558.746            0.025
# std              0.430                513.848            0.155
# min              0.000                190.000            0.000
# 25%              0.000                200.000            0.000
# 50%              0.000                200.000            0.000
# 75%              0.000               1000.000            0.000
# max              1.000               2100.000            1.000
#
#        session_length_in_minutes  keep_alive_session  \
# count                1000000.000         1000000.000
# mean                       7.905               0.560
# std                        8.338               0.496
# min                       -1.000               0.000
# 25%                        3.210               0.000
# 50%                        5.279               1.000
# 75%                        9.420               1.000
# max                       87.237               1.000
#
#        device_distinct_emails_8w  device_fraud_count       month
# count                1000000.000         1000000.000 1000000.000
# mean                       1.024               0.000       3.289
# std                        0.197               0.000       2.210
# min                       -1.000               0.000       0.000
# 25%                        1.000               0.000       1.000
# 50%                        1.000               0.000       3.000
# 75%                        1.000               0.000       5.000
# max                        2.000               0.000       7.000

# %%
df.columns
# Out:
# Index(['fraud_bool', 'income', 'name_email_similarity',
#        'prev_address_months_count', 'current_address_months_count',
#        'customer_age', 'days_since_request', 'intended_balcon_amount',
#        'payment_type', 'zip_count_4w', 'velocity_6h', 'velocity_24h',
#        'velocity_4w', 'bank_branch_count_8w',
#        'date_of_birth_distinct_emails_4w', 'employment_status',
#        'credit_risk_score', 'email_is_free', 'housing_status',
#        'phone_home_valid', 'phone_mobile_valid', 'bank_months_count',
#        'has_other_cards', 'proposed_credit_limit', 'foreign_request', 'source',
#        'session_length_in_minutes', 'device_os', 'keep_alive_session',
#        'device_distinct_emails_8w', 'device_fraud_count', 'month'],
#       dtype='object')

# %% [markdown]
# # Cleaning

# %%
df.isnull().sum()
# Out:
# fraud_bool                          0
# income                              0
# name_email_similarity               0
# prev_address_months_count           0
# current_address_months_count        0
# customer_age                        0
# days_since_request                  0
# intended_balcon_amount              0
# payment_type                        0
# zip_count_4w                        0
# velocity_6h                         0
# velocity_24h                        0
# velocity_4w                         0
# bank_branch_count_8w                0
# date_of_birth_distinct_emails_4w    0
# employment_status                   0
# credit_risk_score                   0
# email_is_free                       0
# housing_status                      0
# phone_home_valid                    0
# phone_mobile_valid                  0
# bank_months_count                   0
# has_other_cards                     0
# proposed_credit_limit               0
# foreign_request                     0
# source                              0
# session_length_in_minutes           0
# device_os                           0
# keep_alive_session                  0
# device_distinct_emails_8w           0
# device_fraud_count                  0
# month                               0
# dtype: int64

# %% [markdown]
# # Feature Engineering and Transformation

# %%
df['month_sin'] = np.sin(2 * np.pi * df['month']/12)
df['month_cos'] = np.cos(2 * np.pi * df['month']/12)

# %%
df.columns
# Out:
# Index(['fraud_bool', 'income', 'name_email_similarity',
#        'prev_address_months_count', 'current_address_months_count',
#        'customer_age', 'days_since_request', 'intended_balcon_amount',
#        'payment_type', 'zip_count_4w', 'velocity_6h', 'velocity_24h',
#        'velocity_4w', 'bank_branch_count_8w',
#        'date_of_birth_distinct_emails_4w', 'employment_status',
#        'credit_risk_score', 'email_is_free', 'housing_status',
#        'phone_home_valid', 'phone_mobile_valid', 'bank_months_count',
#        'has_other_cards', 'proposed_credit_limit', 'foreign_request', 'source',
#        'session_length_in_minutes', 'device_os', 'keep_alive_session',
#        'device_distinct_emails_8w', 'device_fraud_count', 'month', 'month_sin',
#        'month_cos'],
#       dtype='object')

# %%
features = df.drop(columns=['fraud_bool', 'month'])

# %%
numerical_features = features.select_dtypes(include=np.number).columns
numerical_df = features[numerical_features]
print(numerical_df.head())
# Out:
#    income  name_email_similarity  prev_address_months_count  \
# 0   0.700                  0.062                         -1
# 1   0.900                  0.098                         -1
# 2   0.600                  0.117                         -1
# 3   0.300                  0.059                         10
# 4   0.100                  0.690                         -1
#
#    current_address_months_count  customer_age  days_since_request  \
# 0                            24            50               0.017
# 1                           310            50               0.019
# 2                           189            60               0.047
# 3                            40            60               0.008
# 4                           128            30               2.514
#
#    intended_balcon_amount  zip_count_4w  velocity_6h  velocity_24h  \
# 0                  -0.872          3430     8645.190      5569.162
# 1                  -1.024          3492     1610.761      6214.332
# 2                  -1.206          4621     8382.980      6034.593
# 3                  -0.076          1697    13872.725      7594.434
# 4                  -1.108          1431     7755.173      5485.056
#
#    velocity_4w  bank_branch_count_8w  date_of_birth_distinct_emails_4w  \
# 0     6258.579                   615                                 5
# 1     6020.948                    12                                 7
# 2     6772.412                     7                                 8
# 3     5961.464                    29                                14
# 4     5993.340                    10                                10
#
#    credit_risk_score  email_is_free  phone_home_valid  phone_mobile_valid  \
# 0                 55              1                 1                   1
# 1                268              1                 0                   1
# 2                 86              1                 1                   1
# 3                113              1                 0                   1
# 4                115              1                 0                   1
#
#    bank_months_count  has_other_cards  proposed_credit_limit  foreign_request  \
# 0                 30                1                200.000                0
# 1                  5                1               1500.000                0
# 2                 30                0                200.000                0
# 3                  2                1                200.000                0
# 4                 30                0                200.000                0
#
#    session_length_in_minutes  keep_alive_session  device_distinct_emails_8w  \
# 0                      6.804                   0                          1
# 1                      1.412                   0                          1
# 2                     14.489                   1                          1
# 3                      6.152                   1                          1
# 4                      5.600                   0                          1
#
#    device_fraud_count  month_sin  month_cos
# 0                   0      0.000      1.000
# 1                   0      0.000      1.000
# 2                   0      0.000      1.000
# 3                   0      0.000      1.000
# 4                   0      0.000      1.000

# %%
categorical_features = features.select_dtypes(exclude=np.number).columns
categorical_df = features[categorical_features]
print(categorical_df.head())
# Out:
#   payment_type employment_status housing_status    source  device_os
# 0           AB                CB             BC  INTERNET      other
# 1           AB                CA             BA  INTERNET  macintosh
# 2           AB                CB             BC  INTERNET      other
# 3           AA                CA             BC  INTERNET      linux
# 4           AD                CB             BC  INTERNET      other

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

numeric_transformer = StandardScaler()
categorical_transformer = OneHotEncoder(handle_unknown="ignore")

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numerical_features),
        ('cat', categorical_transformer, categorical_features)
    ])
X_scaled = preprocessor.fit_transform(features)
X_scaled_df = pd.DataFrame(X_scaled, columns=preprocessor.get_feature_names_out())
print(X_scaled_df.head())
# Out:
#    num__income  num__name_email_similarity  num__prev_address_months_count  \
# 0        0.434                      -1.463                          -0.366
# 1        1.127                      -1.339                          -0.366
# 2        0.088                      -1.275                          -0.366
# 3       -0.951                      -1.474                          -0.112
# 4       -1.643                       0.691                          -0.366
#
#    num__current_address_months_count  num__customer_age  \
# 0                             -0.797              0.630
# 1                              2.227              0.630
# 2                              0.948              1.354
# 3                             -0.628              1.354
# 4                              0.303             -0.819
#
#    num__days_since_request  num__intended_balcon_amount  num__zip_count_4w  \
# 0                   -0.180                       -0.462              1.845
# 1                   -0.179                       -0.470              1.906
# 2                   -0.173                       -0.479              3.025
# 3                   -0.181                       -0.424              0.128
# 4                    0.321                       -0.474             -0.135
#
#    num__velocity_6h  num__velocity_24h  num__velocity_4w  \
# 0             0.986              0.532             1.525
# 1            -1.357              0.970             1.266
# 2             0.899              0.848             2.086
# 3             2.728              1.909             1.201
# 4             0.690              0.474             1.236
#
#    num__bank_branch_count_8w  num__date_of_birth_distinct_emails_4w  \
# 0                      0.870                                 -0.595
# 1                     -0.402                                 -0.192
# 2                     -0.412                                  0.010
# 3                     -0.366                                  1.219
# 4                     -0.406                                  0.413
#
#    num__credit_risk_score  num__email_is_free  num__phone_home_valid  \
# 0                  -1.142               0.955                  1.021
# 1                   1.808               0.955                 -0.980
# 2                  -0.713               0.955                  1.021
# 3                  -0.339               0.955                 -0.980
# 4                  -0.311               0.955                 -0.980
#
#    num__phone_mobile_valid  num__bank_months_count  num__has_other_cards  \
# 0                    0.411                   1.553                 1.758
# 1                    0.411                  -0.512                 1.758
# 2                    0.411                   1.553                -0.569
# 3                    0.411                  -0.759                 1.758
# 4                    0.411                   1.553                -0.569
#
#    num__proposed_credit_limit  num__foreign_request  \
# 0                      -0.698                -0.159
# 1                       1.832                -0.159
# 2                      -0.698                -0.159
# 3                      -0.698                -0.159
# 4                      -0.698                -0.159
#
#    num__session_length_in_minutes  num__keep_alive_session  \
# 0                          -0.132                   -1.129
# 1                          -0.779                   -1.129
# 2                           0.790                    0.886
# 3                          -0.210                    0.886
# 4                          -0.276                   -1.129
#
#    num__device_distinct_emails_8w  num__device_fraud_count  num__month_sin  \
# 0                          -0.120                    0.000          -0.953
# 1                          -0.120                    0.000          -0.953
# 2                          -0.120                    0.000          -0.953
# 3                          -0.120                    0.000          -0.953
# 4                          -0.120                    0.000          -0.953
#
#    num__month_cos  cat__payment_type_AA  cat__payment_type_AB  \
# 0           1.397                 0.000                 1.000
# 1           1.397                 0.000                 1.000
# 2           1.397                 0.000                 1.000
# 3           1.397                 1.000                 0.000
# 4           1.397                 0.000                 0.000
#
#    cat__payment_type_AC  cat__payment_type_AD  cat__payment_type_AE  \
# 0                 0.000                 0.000                 0.000
# 1                 0.000                 0.000                 0.000
# 2                 0.000                 0.000                 0.000
# 3                 0.000                 0.000                 0.000
# 4                 0.000                 1.000                 0.000
#
#    cat__employment_status_CA  cat__employment_status_CB  \
# 0                      0.000                      1.000
# 1                      1.000                      0.000
# 2                      0.000                      1.000
# 3                      1.000                      0.000
# 4                      0.000                      1.000
#
#    cat__employment_status_CC  cat__employment_status_CD  \
# 0                      0.000                      0.000
# 1                      0.000                      0.000
# 2                      0.000                      0.000
# 3                      0.000                      0.000
# 4                      0.000                      0.000
#
#    cat__employment_status_CE  cat__employment_status_CF  \
# 0                      0.000                      0.000
# 1                      0.000                      0.000
# 2                      0.000                      0.000
# 3                      0.000                      0.000
# 4                      0.000                      0.000
#
#    cat__employment_status_CG  cat__housing_status_BA  cat__housing_status_BB  \
# 0                      0.000                   0.000                   0.000
# 1                      0.000                   1.000                   0.000
# 2                      0.000                   0.000                   0.000
# 3                      0.000                   0.000                   0.000
# 4                      0.000                   0.000                   0.000
#
#    cat__housing_status_BC  cat__housing_status_BD  cat__housing_status_BE  \
# 0                   1.000                   0.000                   0.000
# 1                   0.000                   0.000                   0.000
# 2                   1.000                   0.000                   0.000
# 3                   1.000                   0.000                   0.000
# 4                   1.000                   0.000                   0.000
#
#    cat__housing_status_BF  cat__housing_status_BG  cat__source_INTERNET  \
# 0                   0.000                   0.000                 1.000
# 1                   0.000                   0.000                 1.000
# 2                   0.000                   0.000                 1.000
# 3                   0.000                   0.000                 1.000
# 4                   0.000                   0.000                 1.000
#
#    cat__source_TELEAPP  cat__device_os_linux  cat__device_os_macintosh  \
# 0                0.000                 0.000                     0.000
# 1                0.000                 0.000                     1.000
# 2                0.000                 0.000                     0.000
# 3                0.000                 1.000                     0.000
# 4                0.000                 0.000                     0.000
#
#    cat__device_os_other  cat__device_os_windows  cat__device_os_x11
# 0                 1.000                   0.000               0.000
# 1                 0.000                   0.000               0.000
# 2                 1.000                   0.000               0.000
# 3                 0.000                   0.000               0.000
# 4                 1.000                   0.000               0.000

# %%
print(X_scaled_df.info())
print(X_scaled_df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 53 columns):
#  #   Column                                 Non-Null Count    Dtype
# ---  ------                                 --------------    -----
#  0   num__income                            1000000 non-null  float64
#  1   num__name_email_similarity             1000000 non-null  float64
#  2   num__prev_address_months_count         1000000 non-null  float64
#  3   num__current_address_months_count      1000000 non-null  float64
#  4   num__customer_age                      1000000 non-null  float64
#  5   num__days_since_request                1000000 non-null  float64
#  6   num__intended_balcon_amount            1000000 non-null  float64
#  7   num__zip_count_4w                      1000000 non-null  float64
#  8   num__velocity_6h                       1000000 non-null  float64
#  9   num__velocity_24h                      1000000 non-null  float64
#  10  num__velocity_4w                       1000000 non-null  float64
#  11  num__bank_branch_count_8w              1000000 non-null  float64
#  12  num__date_of_birth_distinct_emails_4w  1000000 non-null  float64
#  13  num__credit_risk_score                 1000000 non-null  float64
#  14  num__email_is_free                     1000000 non-null  float64
#  15  num__phone_home_valid                  1000000 non-null  float64
#  16  num__phone_mobile_valid                1000000 non-null  float64
#  17  num__bank_months_count                 1000000 non-null  float64
#  18  num__has_other_cards                   1000000 non-null  float64
#  19  num__proposed_credit_limit             1000000 non-null  float64
#  20  num__foreign_request                   1000000 non-null  float64
#  21  num__session_length_in_minutes         1000000 non-null  float64
#  22  num__keep_alive_session                1000000 non-null  float64
#  23  num__device_distinct_emails_8w         1000000 non-null  float64
#  24  num__device_fraud_count                1000000 non-null  float64
#  25  num__month_sin                         1000000 non-null  float64
#  26  num__month_cos                         1000000 non-null  float64
#  27  cat__payment_type_AA                   1000000 non-null  float64
#  28  cat__payment_type_AB                   1000000 non-null  float64
#  29  cat__payment_type_AC                   1000000 non-null  float64
#  30  cat__payment_type_AD                   1000000 non-null  float64
#  31  cat__payment_type_AE                   1000000 non-null  float64
#  32  cat__employment_status_CA              1000000 non-null  float64
#  33  cat__employment_status_CB              1000000 non-null  float64
#  34  cat__employment_status_CC              1000000 non-null  float64
#  35  cat__employment_status_CD              1000000 non-null  float64
#  36  cat__employment_status_CE              1000000 non-null  float64
#  37  cat__employment_status_CF              1000000 non-null  float64
#  38  cat__employment_status_CG              1000000 non-null  float64
#  39  cat__housing_status_BA                 1000000 non-null  float64
#  40  cat__housing_status_BB                 1000000 non-null  float64
#  41  cat__housing_status_BC                 1000000 non-null  float64
#  42  cat__housing_status_BD                 1000000 non-null  float64
#  43  cat__housing_status_BE                 1000000 non-null  float64
#  44  cat__housing_status_BF                 1000000 non-null  float64
#  45  cat__housing_status_BG                 1000000 non-null  float64
#  46  cat__source_INTERNET                   1000000 non-null  float64
#  47  cat__source_TELEAPP                    1000000 non-null  float64
#  48  cat__device_os_linux                   1000000 non-null  float64
#  49  cat__device_os_macintosh               1000000 non-null  float64
#  50  cat__device_os_other                   1000000 non-null  float64
#  51  cat__device_os_windows                 1000000 non-null  float64
#  52  cat__device_os_x11                     1000000 non-null  float64
# dtypes: float64(53)
# memory usage: 404.4 MB
# None
#        num__income  num__name_email_similarity  \
# count  1000000.000                 1000000.000
# mean         0.000                       0.000
# std          1.000                       1.000
# min         -1.643                      -1.677
# 25%         -0.951                      -0.940
# 50%          0.088                       0.004
# 75%          0.781                       0.912
# max          1.127                       1.755
#
#        num__prev_address_months_count  num__current_address_months_count  \
# count                     1000000.000                        1000000.000
# mean                            0.000                             -0.000
# std                             1.000                              1.000
# min                            -0.366                             -1.062
# 25%                            -0.366                             -0.776
# 50%                            -0.366                             -0.374
# 75%                            -0.366                              0.578
# max                             8.886                              3.486
#
#        num__customer_age  num__days_since_request  \
# count        1000000.000              1000000.000
# mean               0.000                    0.000
# std                1.000                    1.000
# min               -2.268                   -0.183
# 25%               -0.819                   -0.181
# 50%                0.630                   -0.180
# 75%                0.630                   -0.177
# max                3.527                   15.173
#
#        num__intended_balcon_amount  num__zip_count_4w  num__velocity_6h  \
# count                  1000000.000        1000000.000       1000000.000
# mean                        -0.000             -0.000            -0.000
# std                          1.000              1.000             1.000
# min                         -1.185             -1.551            -1.952
# 25%                         -0.477             -0.660            -0.738
# 50%                         -0.460             -0.328            -0.092
# 75%                         -0.416              0.338             0.656
# max                          5.058              5.034             3.703
#
#        num__velocity_24h  num__velocity_4w  num__bank_branch_count_8w  \
# count        1000000.000       1000000.000                1000000.000
# mean               0.000             0.000                      0.000
# std                1.000             1.000                      1.000
# min               -2.357            -2.170                     -0.427
# 25%               -0.788            -0.643                     -0.425
# 50%               -0.015             0.064                     -0.406
# 75%                0.655             0.686                     -0.360
# max                3.232             2.355                      4.586
#
#        num__date_of_birth_distinct_emails_4w  num__credit_risk_score  \
# count                            1000000.000             1000000.000
# mean                                   0.000                  -0.000
# std                                    1.000                   1.000
# min                                   -1.603                  -4.549
# 25%                                   -0.797                  -0.699
# 50%                                   -0.192                  -0.131
# 75%                                    0.615                   0.686
# max                                    6.259                   3.470
#
#        num__email_is_free  num__phone_home_valid  num__phone_mobile_valid  \
# count         1000000.000            1000000.000              1000000.000
# mean               -0.000                 -0.000                    0.000
# std                 1.000                  1.000                    1.000
# min                -1.048                 -0.980                   -2.430
# 25%                -1.048                 -0.980                    0.411
# 50%                 0.955                 -0.980                    0.411
# 75%                 0.955                  1.021                    0.411
# max                 0.955                  1.021                    0.411
#
#        num__bank_months_count  num__has_other_cards  \
# count             1000000.000           1000000.000
# mean                   -0.000                -0.000
# std                     1.000                 1.000
# min                    -1.007                -0.569
# 25%                    -0.842                -0.569
# 50%                    -0.429                -0.569
# 75%                     1.140                -0.569
# max                     1.718                 1.758
#
#        num__proposed_credit_limit  num__foreign_request  \
# count                 1000000.000           1000000.000
# mean                       -0.000                -0.000
# std                         1.000                 1.000
# min                        -0.718                -0.159
# 25%                        -0.698                -0.159
# 50%                        -0.698                -0.159
# 75%                         0.859                -0.159
# max                         2.999                 6.283
#
#        num__session_length_in_minutes  num__keep_alive_session  \
# count                     1000000.000              1000000.000
# mean                           -0.000                    0.000
# std                             1.000                    1.000
# min                            -1.068                   -1.129
# 25%                            -0.563                   -1.129
# 50%                            -0.315                    0.886
# 75%                             0.182                    0.886
# max                             9.514                    0.886
#
#        num__device_distinct_emails_8w  num__device_fraud_count  \
# count                     1000000.000              1000000.000
# mean                           -0.000                    0.000
# std                             1.000                    0.000
# min                           -10.251                    0.000
# 25%                            -0.120                    0.000
# 50%                            -0.120                    0.000
# 75%                            -0.120                    0.000
# max                             4.946                    0.000
#
#        num__month_sin  num__month_cos  cat__payment_type_AA  \
# count     1000000.000     1000000.000           1000000.000
# mean           -0.000           0.000                 0.252
# std             1.000           1.000                 0.434
# min            -2.000          -1.270                 0.000
# 25%            -0.953          -1.091                 0.000
# 50%             0.094           0.064                 0.000
# 75%             0.860           1.219                 1.000
# max             1.141           1.397                 1.000
#
#        cat__payment_type_AB  cat__payment_type_AC  cat__payment_type_AD  \
# count           1000000.000           1000000.000           1000000.000
# mean                  0.395                 0.242                 0.111
# std                   0.489                 0.428                 0.314
# min                   0.000                 0.000                 0.000
# 25%                   0.000                 0.000                 0.000
# 50%                   0.000                 0.000                 0.000
# 75%                   1.000                 0.000                 0.000
# max                   1.000                 1.000                 1.000
#
#        cat__payment_type_AE  cat__employment_status_CA  \
# count           1000000.000                1000000.000
# mean                  0.000                      0.678
# std                   0.016                      0.467
# min                   0.000                      0.000
# 25%                   0.000                      0.000
# 50%                   0.000                      1.000
# 75%                   0.000                      1.000
# max                   1.000                      1.000
#
#        cat__employment_status_CB  cat__employment_status_CC  \
# count                1000000.000                1000000.000
# mean                       0.142                      0.089
# std                        0.349                      0.285
# min                        0.000                      0.000
# 25%                        0.000                      0.000
# 50%                        0.000                      0.000
# 75%                        0.000                      0.000
# max                        1.000                      1.000
#
#        cat__employment_status_CD  cat__employment_status_CE  \
# count                1000000.000                1000000.000
# mean                       0.027                      0.019
# std                        0.163                      0.136
# min                        0.000                      0.000
# 25%                        0.000                      0.000
# 50%                        0.000                      0.000
# 75%                        0.000                      0.000
# max                        1.000                      1.000
#
#        cat__employment_status_CF  cat__employment_status_CG  \
# count                1000000.000                1000000.000
# mean                       0.045                      0.000
# std                        0.207                      0.022
# min                        0.000                      0.000
# 25%                        0.000                      0.000
# 50%                        0.000                      0.000
# 75%                        0.000                      0.000
# max                        1.000                      1.000
#
#        cat__housing_status_BA  cat__housing_status_BB  cat__housing_status_BC  \
# count             1000000.000             1000000.000             1000000.000
# mean                    0.215                   0.295                   0.340
# std                     0.411                   0.456                   0.474
# min                     0.000                   0.000                   0.000
# 25%                     0.000                   0.000                   0.000
# 50%                     0.000                   0.000                   0.000
# 75%                     0.000                   1.000                   1.000
# max                     1.000                   1.000                   1.000
#
#        cat__housing_status_BD  cat__housing_status_BE  cat__housing_status_BF  \
# count             1000000.000             1000000.000             1000000.000
# mean                    0.026                   0.122                   0.002
# std                     0.160                   0.327                   0.041
# min                     0.000                   0.000                   0.000
# 25%                     0.000                   0.000                   0.000
# 50%                     0.000                   0.000                   0.000
# 75%                     0.000                   0.000                   0.000
# max                     1.000                   1.000                   1.000
#
#        cat__housing_status_BG  cat__source_INTERNET  cat__source_TELEAPP  \
# count             1000000.000           1000000.000          1000000.000
# mean                    0.000                 0.992                0.008
# std                     0.017                 0.088                0.088
# min                     0.000                 0.000                0.000
# 25%                     0.000                 1.000                0.000
# 50%                     0.000                 1.000                0.000
# 75%                     0.000                 1.000                0.000
# max                     1.000                 1.000                1.000
#
#        cat__device_os_linux  cat__device_os_macintosh  cat__device_os_other  \
# count           1000000.000               1000000.000           1000000.000
# mean                  0.339                     0.049                 0.300
# std                   0.473                     0.216                 0.458
# min                   0.000                     0.000                 0.000
# 25%                   0.000                     0.000                 0.000
# 50%                   0.000                     0.000                 0.000
# 75%                   1.000                     0.000                 1.000
# max                   1.000                     1.000                 1.000
#
#        cat__device_os_windows  cat__device_os_x11
# count             1000000.000         1000000.000
# mean                    0.304               0.008
# std                     0.460               0.090
# min                     0.000               0.000
# 25%                     0.000               0.000
# 50%                     0.000               0.000
# 75%                     1.000               0.000
# max                     1.000               1.000

# %%
X_scaled_df.columns
# Out:
# Index(['num__income', 'num__name_email_similarity',
#        'num__prev_address_months_count', 'num__current_address_months_count',
#        'num__customer_age', 'num__days_since_request',
#        'num__intended_balcon_amount', 'num__zip_count_4w', 'num__velocity_6h',
#        'num__velocity_24h', 'num__velocity_4w', 'num__bank_branch_count_8w',
#        'num__date_of_birth_distinct_emails_4w', 'num__credit_risk_score',
#        'num__email_is_free', 'num__phone_home_valid',
#        'num__phone_mobile_valid', 'num__bank_months_count',
#        'num__has_other_cards', 'num__proposed_credit_limit',
#        'num__foreign_request', 'num__session_length_in_minutes',
#        'num__keep_alive_session', 'num__device_distinct_emails_8w',
#        'num__device_fraud_count', 'num__month_sin', 'num__month_cos',
#        'cat__payment_type_AA', 'cat__payment_type_AB', 'cat__payment_type_AC',
#        'cat__payment_type_AD', 'cat__payment_type_AE',
#        'cat__employment_status_CA', 'cat__employment_status_CB',
#        'cat__employment_status_CC', 'cat__employment_status_CD',
#        'cat__employment_status_CE', 'cat__employment_status_CF',
#        'cat__employment_status_CG', 'cat__housing_status_BA',
#        'cat__housing_status_BB', 'cat__housing_status_BC',
#        'cat__housing_status_BD', 'cat__housing_status_BE',
#        'cat__housing_status_BF', 'cat__housing_status_BG',
#        'cat__source_INTERNET', 'cat__source_TELEAPP', 'cat__device_os_linux',
#        'cat__device_os_macintosh', 'cat__device_os_other',
#        'cat__device_os_windows', 'cat__device_os_x11'],
#       dtype='object')

# %%
df.shape
# Out:
# (1000000, 34)

# %%
features.shape
# Out:
# (1000000, 32)

# %%
X_scaled.shape
# Out:
# (1000000, 53)

# %%
save_path = "/content/drive/MyDrive/Professional/Portfolio/Fraud Detection/Data/Preprocessed/Variant II/X_scaled.csv"
X_scaled_df.to_csv(save_path, index=False)

# %%
import pickle

save_path = "/content/drive/MyDrive/Professional/Portfolio/Fraud Detection/Data/Preprocessed/Variant II/X_scaled.pkl"
with open(save_path, 'wb') as file:
    pickle.dump(X_scaled, file)

# %% [markdown]
# # Fraud Detection Included

# %% [markdown]
# Below, I created a transformed dataset where fraud_bool is included for visualization purposes.

# %% [markdown]
# ## Clean & Process

# %% [markdown]
# ## Setup

# %%
file_path = "/content/drive/MyDrive/Professional/Portfolio/Fraud Detection/Data/Variant II.csv/fifar_variant_II.csv"

try:
  df = pd.read_csv(file_path)
  print("DataFrame loaded successfully.")
except FileNotFoundError:
  print(f"Error: File not found at {file_path}")
except pd.errors.ParserError:
  print(f"Error: Unable to parse the CSV file at {file_path}. Check the file format.")
except Exception as e:
  print(f"An unexpected error occurred: {e}")
# Out:
# DataFrame loaded successfully.

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# ## Feature Engineering and Transformation

# %%
df['month_sin'] = np.sin(2 * np.pi * df['month']/12)
df['month_cos'] = np.cos(2 * np.pi * df['month']/12)

# %%
df.columns
# Out:
# Index(['fraud_bool', 'income', 'name_email_similarity',
#        'prev_address_months_count', 'current_address_months_count',
#        'customer_age', 'days_since_request', 'intended_balcon_amount',
#        'payment_type', 'zip_count_4w', 'velocity_6h', 'velocity_24h',
#        'velocity_4w', 'bank_branch_count_8w',
#        'date_of_birth_distinct_emails_4w', 'employment_status',
#        'credit_risk_score', 'email_is_free', 'housing_status',
#        'phone_home_valid', 'phone_mobile_valid', 'bank_months_count',
#        'has_other_cards', 'proposed_credit_limit', 'foreign_request', 'source',
#        'session_length_in_minutes', 'device_os', 'keep_alive_session',
#        'device_distinct_emails_8w', 'device_fraud_count', 'month', 'month_sin',
#        'month_cos'],
#       dtype='object')

# %%
features = df.drop(columns=['month'])

# %%
numerical_features = features.select_dtypes(include=np.number).columns
numerical_df = features[numerical_features]
print(numerical_df.head())
# Out:
#    fraud_bool  income  name_email_similarity  prev_address_months_count  \
# 0           0   0.700                  0.062                         -1
# 1           0   0.900                  0.098                         -1
# 2           0   0.600                  0.117                         -1
# 3           0   0.300                  0.059                         10
# 4           0   0.100                  0.690                         -1
#
#    current_address_months_count  customer_age  days_since_request  \
# 0                            24            50               0.017
# 1                           310            50               0.019
# 2                           189            60               0.047
# 3                            40            60               0.008
# 4                           128            30               2.514
#
#    intended_balcon_amount  zip_count_4w  velocity_6h  velocity_24h  \
# 0                  -0.872          3430     8645.190      5569.162
# 1                  -1.024          3492     1610.761      6214.332
# 2                  -1.206          4621     8382.980      6034.593
# 3                  -0.076          1697    13872.725      7594.434
# 4                  -1.108          1431     7755.173      5485.056
#
#    velocity_4w  bank_branch_count_8w  date_of_birth_distinct_emails_4w  \
# 0     6258.579                   615                                 5
# 1     6020.948                    12                                 7
# 2     6772.412                     7                                 8
# 3     5961.464                    29                                14
# 4     5993.340                    10                                10
#
#    credit_risk_score  email_is_free  phone_home_valid  phone_mobile_valid  \
# 0                 55              1                 1                   1
# 1                268              1                 0                   1
# 2                 86              1                 1                   1
# 3                113              1                 0                   1
# 4                115              1                 0                   1
#
#    bank_months_count  has_other_cards  proposed_credit_limit  foreign_request  \
# 0                 30                1                200.000                0
# 1                  5                1               1500.000                0
# 2                 30                0                200.000                0
# 3                  2                1                200.000                0
# 4                 30                0                200.000                0
#
#    session_length_in_minutes  keep_alive_session  device_distinct_emails_8w  \
# 0                      6.804                   0                          1
# 1                      1.412                   0                          1
# 2                     14.489                   1                          1
# 3                      6.152                   1                          1
# 4                      5.600                   0                          1
#
#    device_fraud_count  month_sin  month_cos
# 0                   0      0.000      1.000
# 1                   0      0.000      1.000
# 2                   0      0.000      1.000
# 3                   0      0.000      1.000
# 4                   0      0.000      1.000

# %%
categorical_features = features.select_dtypes(exclude=np.number).columns
categorical_df = features[categorical_features]
print(categorical_df.head())
# Out:
#   payment_type employment_status housing_status    source  device_os
# 0           AB                CB             BC  INTERNET      other
# 1           AB                CA             BA  INTERNET  macintosh
# 2           AB                CB             BC  INTERNET      other
# 3           AA                CA             BC  INTERNET      linux
# 4           AD                CB             BC  INTERNET      other

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

numeric_transformer = StandardScaler()
categorical_transformer = OneHotEncoder(handle_unknown="ignore")

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numerical_features),
        ('cat', categorical_transformer, categorical_features)
    ])
X_scaled_full = preprocessor.fit_transform(features)
X_scaled_full_df = pd.DataFrame(X_scaled_full, columns=preprocessor.get_feature_names_out())
print(X_scaled_full_df.head())
# Out:
#    num__fraud_bool  num__income  num__name_email_similarity  \
# 0           -0.106        0.434                      -1.463
# 1           -0.106        1.127                      -1.339
# 2           -0.106        0.088                      -1.275
# 3           -0.106       -0.951                      -1.474
# 4           -0.106       -1.643                       0.691
#
#    num__prev_address_months_count  num__current_address_months_count  \
# 0                          -0.366                             -0.797
# 1                          -0.366                              2.227
# 2                          -0.366                              0.948
# 3                          -0.112                             -0.628
# 4                          -0.366                              0.303
#
#    num__customer_age  num__days_since_request  num__intended_balcon_amount  \
# 0              0.630                   -0.180                       -0.462
# 1              0.630                   -0.179                       -0.470
# 2              1.354                   -0.173                       -0.479
# 3              1.354                   -0.181                       -0.424
# 4             -0.819                    0.321                       -0.474
#
#    num__zip_count_4w  num__velocity_6h  num__velocity_24h  num__velocity_4w  \
# 0              1.845             0.986              0.532             1.525
# 1              1.906            -1.357              0.970             1.266
# 2              3.025             0.899              0.848             2.086
# 3              0.128             2.728              1.909             1.201
# 4             -0.135             0.690              0.474             1.236
#
#    num__bank_branch_count_8w  num__date_of_birth_distinct_emails_4w  \
# 0                      0.870                                 -0.595
# 1                     -0.402                                 -0.192
# 2                     -0.412                                  0.010
# 3                     -0.366                                  1.219
# 4                     -0.406                                  0.413
#
#    num__credit_risk_score  num__email_is_free  num__phone_home_valid  \
# 0                  -1.142               0.955                  1.021
# 1                   1.808               0.955                 -0.980
# 2                  -0.713               0.955                  1.021
# 3                  -0.339               0.955                 -0.980
# 4                  -0.311               0.955                 -0.980
#
#    num__phone_mobile_valid  num__bank_months_count  num__has_other_cards  \
# 0                    0.411                   1.553                 1.758
# 1                    0.411                  -0.512                 1.758
# 2                    0.411                   1.553                -0.569
# 3                    0.411                  -0.759                 1.758
# 4                    0.411                   1.553                -0.569
#
#    num__proposed_credit_limit  num__foreign_request  \
# 0                      -0.698                -0.159
# 1                       1.832                -0.159
# 2                      -0.698                -0.159
# 3                      -0.698                -0.159
# 4                      -0.698                -0.159
#
#    num__session_length_in_minutes  num__keep_alive_session  \
# 0                          -0.132                   -1.129
# 1                          -0.779                   -1.129
# 2                           0.790                    0.886
# 3                          -0.210                    0.886
# 4                          -0.276                   -1.129
#
#    num__device_distinct_emails_8w  num__device_fraud_count  num__month_sin  \
# 0                          -0.120                    0.000          -0.953
# 1                          -0.120                    0.000          -0.953
# 2                          -0.120                    0.000          -0.953
# 3                          -0.120                    0.000          -0.953
# 4                          -0.120                    0.000          -0.953
#
#    num__month_cos  cat__payment_type_AA  cat__payment_type_AB  \
# 0           1.397                 0.000                 1.000
# 1           1.397                 0.000                 1.000
# 2           1.397                 0.000                 1.000
# 3           1.397                 1.000                 0.000
# 4           1.397                 0.000                 0.000
#
#    cat__payment_type_AC  cat__payment_type_AD  cat__payment_type_AE  \
# 0                 0.000                 0.000                 0.000
# 1                 0.000                 0.000                 0.000
# 2                 0.000                 0.000                 0.000
# 3                 0.000                 0.000                 0.000
# 4                 0.000                 1.000                 0.000
#
#    cat__employment_status_CA  cat__employment_status_CB  \
# 0                      0.000                      1.000
# 1                      1.000                      0.000
# 2                      0.000                      1.000
# 3                      1.000                      0.000
# 4                      0.000                      1.000
#
#    cat__employment_status_CC  cat__employment_status_CD  \
# 0                      0.000                      0.000
# 1                      0.000                      0.000
# 2                      0.000                      0.000
# 3                      0.000                      0.000
# 4                      0.000                      0.000
#
#    cat__employment_status_CE  cat__employment_status_CF  \
# 0                      0.000                      0.000
# 1                      0.000                      0.000
# 2                      0.000                      0.000
# 3                      0.000                      0.000
# 4                      0.000                      0.000
#
#    cat__employment_status_CG  cat__housing_status_BA  cat__housing_status_BB  \
# 0                      0.000                   0.000                   0.000
# 1                      0.000                   1.000                   0.000
# 2                      0.000                   0.000                   0.000
# 3                      0.000                   0.000                   0.000
# 4                      0.000                   0.000                   0.000
#
#    cat__housing_status_BC  cat__housing_status_BD  cat__housing_status_BE  \
# 0                   1.000                   0.000                   0.000
# 1                   0.000                   0.000                   0.000
# 2                   1.000                   0.000                   0.000
# 3                   1.000                   0.000                   0.000
# 4                   1.000                   0.000                   0.000
#
#    cat__housing_status_BF  cat__housing_status_BG  cat__source_INTERNET  \
# 0                   0.000                   0.000                 1.000
# 1                   0.000                   0.000                 1.000
# 2                   0.000                   0.000                 1.000
# 3                   0.000                   0.000                 1.000
# 4                   0.000                   0.000                 1.000
#
#    cat__source_TELEAPP  cat__device_os_linux  cat__device_os_macintosh  \
# 0                0.000                 0.000                     0.000
# 1                0.000                 0.000                     1.000
# 2                0.000                 0.000                     0.000
# 3                0.000                 1.000                     0.000
# 4                0.000                 0.000                     0.000
#
#    cat__device_os_other  cat__device_os_windows  cat__device_os_x11
# 0                 1.000                   0.000               0.000
# 1                 0.000                   0.000               0.000
# 2                 1.000                   0.000               0.000
# 3                 0.000                   0.000               0.000
# 4                 1.000                   0.000               0.000

# %%
print(X_scaled_full_df.info())
print(X_scaled_full_df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 54 columns):
#  #   Column                                 Non-Null Count    Dtype
# ---  ------                                 --------------    -----
#  0   num__fraud_bool                        1000000 non-null  float64
#  1   num__income                            1000000 non-null  float64
#  2   num__name_email_similarity             1000000 non-null  float64
#  3   num__prev_address_months_count         1000000 non-null  float64
#  4   num__current_address_months_count      1000000 non-null  float64
#  5   num__customer_age                      1000000 non-null  float64
#  6   num__days_since_request                1000000 non-null  float64
#  7   num__intended_balcon_amount            1000000 non-null  float64
#  8   num__zip_count_4w                      1000000 non-null  float64
#  9   num__velocity_6h                       1000000 non-null  float64
#  10  num__velocity_24h                      1000000 non-null  float64
#  11  num__velocity_4w                       1000000 non-null  float64
#  12  num__bank_branch_count_8w              1000000 non-null  float64
#  13  num__date_of_birth_distinct_emails_4w  1000000 non-null  float64
#  14  num__credit_risk_score                 1000000 non-null  float64
#  15  num__email_is_free                     1000000 non-null  float64
#  16  num__phone_home_valid                  1000000 non-null  float64
#  17  num__phone_mobile_valid                1000000 non-null  float64
#  18  num__bank_months_count                 1000000 non-null  float64
#  19  num__has_other_cards                   1000000 non-null  float64
#  20  num__proposed_credit_limit             1000000 non-null  float64
#  21  num__foreign_request                   1000000 non-null  float64
#  22  num__session_length_in_minutes         1000000 non-null  float64
#  23  num__keep_alive_session                1000000 non-null  float64
#  24  num__device_distinct_emails_8w         1000000 non-null  float64
#  25  num__device_fraud_count                1000000 non-null  float64
#  26  num__month_sin                         1000000 non-null  float64
#  27  num__month_cos                         1000000 non-null  float64
#  28  cat__payment_type_AA                   1000000 non-null  float64
#  29  cat__payment_type_AB                   1000000 non-null  float64
#  30  cat__payment_type_AC                   1000000 non-null  float64
#  31  cat__payment_type_AD                   1000000 non-null  float64
#  32  cat__payment_type_AE                   1000000 non-null  float64
#  33  cat__employment_status_CA              1000000 non-null  float64
#  34  cat__employment_status_CB              1000000 non-null  float64
#  35  cat__employment_status_CC              1000000 non-null  float64
#  36  cat__employment_status_CD              1000000 non-null  float64
#  37  cat__employment_status_CE              1000000 non-null  float64
#  38  cat__employment_status_CF              1000000 non-null  float64
#  39  cat__employment_status_CG              1000000 non-null  float64
#  40  cat__housing_status_BA                 1000000 non-null  float64
#  41  cat__housing_status_BB                 1000000 non-null  float64
#  42  cat__housing_status_BC                 1000000 non-null  float64
#  43  cat__housing_status_BD                 1000000 non-null  float64
#  44  cat__housing_status_BE                 1000000 non-null  float64
#  45  cat__housing_status_BF                 1000000 non-null  float64
#  46  cat__housing_status_BG                 1000000 non-null  float64
#  47  cat__source_INTERNET                   1000000 non-null  float64
#  48  cat__source_TELEAPP                    1000000 non-null  float64
#  49  cat__device_os_linux                   1000000 non-null  float64
#  50  cat__device_os_macintosh               1000000 non-null  float64
#  51  cat__device_os_other                   1000000 non-null  float64
#  52  cat__device_os_windows                 1000000 non-null  float64
#  53  cat__device_os_x11                     1000000 non-null  float64
# dtypes: float64(54)
# memory usage: 412.0 MB
# None
#        num__fraud_bool  num__income  num__name_email_similarity  \
# count      1000000.000  1000000.000                 1000000.000
# mean             0.000        0.000                       0.000
# std              1.000        1.000                       1.000
# min             -0.106       -1.643                      -1.677
# 25%             -0.106       -0.951                      -0.940
# 50%             -0.106        0.088                       0.004
# 75%             -0.106        0.781                       0.912
# max              9.469        1.127                       1.755
#
#        num__prev_address_months_count  num__current_address_months_count  \
# count                     1000000.000                        1000000.000
# mean                            0.000                             -0.000
# std                             1.000                              1.000
# min                            -0.366                             -1.062
# 25%                            -0.366                             -0.776
# 50%                            -0.366                             -0.374
# 75%                            -0.366                              0.578
# max                             8.886                              3.486
#
#        num__customer_age  num__days_since_request  \
# count        1000000.000              1000000.000
# mean               0.000                    0.000
# std                1.000                    1.000
# min               -2.268                   -0.183
# 25%               -0.819                   -0.181
# 50%                0.630                   -0.180
# 75%                0.630                   -0.177
# max                3.527                   15.173
#
#        num__intended_balcon_amount  num__zip_count_4w  num__velocity_6h  \
# count                  1000000.000        1000000.000       1000000.000
# mean                        -0.000             -0.000            -0.000
# std                          1.000              1.000             1.000
# min                         -1.185             -1.551            -1.952
# 25%                         -0.477             -0.660            -0.738
# 50%                         -0.460             -0.328            -0.092
# 75%                         -0.416              0.338             0.656
# max                          5.058              5.034             3.703
#
#        num__velocity_24h  num__velocity_4w  num__bank_branch_count_8w  \
# count        1000000.000       1000000.000                1000000.000
# mean               0.000             0.000                      0.000
# std                1.000             1.000                      1.000
# min               -2.357            -2.170                     -0.427
# 25%               -0.788            -0.643                     -0.425
# 50%               -0.015             0.064                     -0.406
# 75%                0.655             0.686                     -0.360
# max                3.232             2.355                      4.586
#
#        num__date_of_birth_distinct_emails_4w  num__credit_risk_score  \
# count                            1000000.000             1000000.000
# mean                                   0.000                  -0.000
# std                                    1.000                   1.000
# min                                   -1.603                  -4.549
# 25%                                   -0.797                  -0.699
# 50%                                   -0.192                  -0.131
# 75%                                    0.615                   0.686
# max                                    6.259                   3.470
#
#        num__email_is_free  num__phone_home_valid  num__phone_mobile_valid  \
# count         1000000.000            1000000.000              1000000.000
# mean               -0.000                 -0.000                    0.000
# std                 1.000                  1.000                    1.000
# min                -1.048                 -0.980                   -2.430
# 25%                -1.048                 -0.980                    0.411
# 50%                 0.955                 -0.980                    0.411
# 75%                 0.955                  1.021                    0.411
# max                 0.955                  1.021                    0.411
#
#        num__bank_months_count  num__has_other_cards  \
# count             1000000.000           1000000.000
# mean                   -0.000                -0.000
# std                     1.000                 1.000
# min                    -1.007                -0.569
# 25%                    -0.842                -0.569
# 50%                    -0.429                -0.569
# 75%                     1.140                -0.569
# max                     1.718                 1.758
#
#        num__proposed_credit_limit  num__foreign_request  \
# count                 1000000.000           1000000.000
# mean                       -0.000                -0.000
# std                         1.000                 1.000
# min                        -0.718                -0.159
# 25%                        -0.698                -0.159
# 50%                        -0.698                -0.159
# 75%                         0.859                -0.159
# max                         2.999                 6.283
#
#        num__session_length_in_minutes  num__keep_alive_session  \
# count                     1000000.000              1000000.000
# mean                           -0.000                    0.000
# std                             1.000                    1.000
# min                            -1.068                   -1.129
# 25%                            -0.563                   -1.129
# 50%                            -0.315                    0.886
# 75%                             0.182                    0.886
# max                             9.514                    0.886
#
#        num__device_distinct_emails_8w  num__device_fraud_count  \
# count                     1000000.000              1000000.000
# mean                           -0.000                    0.000
# std                             1.000                    0.000
# min                           -10.251                    0.000
# 25%                            -0.120                    0.000
# 50%                            -0.120                    0.000
# 75%                            -0.120                    0.000
# max                             4.946                    0.000
#
#        num__month_sin  num__month_cos  cat__payment_type_AA  \
# count     1000000.000     1000000.000           1000000.000
# mean           -0.000           0.000                 0.252
# std             1.000           1.000                 0.434
# min            -2.000          -1.270                 0.000
# 25%            -0.953          -1.091                 0.000
# 50%             0.094           0.064                 0.000
# 75%             0.860           1.219                 1.000
# max             1.141           1.397                 1.000
#
#        cat__payment_type_AB  cat__payment_type_AC  cat__payment_type_AD  \
# count           1000000.000           1000000.000           1000000.000
# mean                  0.395                 0.242                 0.111
# std                   0.489                 0.428                 0.314
# min                   0.000                 0.000                 0.000
# 25%                   0.000                 0.000                 0.000
# 50%                   0.000                 0.000                 0.000
# 75%                   1.000                 0.000                 0.000
# max                   1.000                 1.000                 1.000
#
#        cat__payment_type_AE  cat__employment_status_CA  \
# count           1000000.000                1000000.000
# mean                  0.000                      0.678
# std                   0.016                      0.467
# min                   0.000                      0.000
# 25%                   0.000                      0.000
# 50%                   0.000                      1.000
# 75%                   0.000                      1.000
# max                   1.000                      1.000
#
#        cat__employment_status_CB  cat__employment_status_CC  \
# count                1000000.000                1000000.000
# mean                       0.142                      0.089
# std                        0.349                      0.285
# min                        0.000                      0.000
# 25%                        0.000                      0.000
# 50%                        0.000                      0.000
# 75%                        0.000                      0.000
# max                        1.000                      1.000
#
#        cat__employment_status_CD  cat__employment_status_CE  \
# count                1000000.000                1000000.000
# mean                       0.027                      0.019
# std                        0.163                      0.136
# min                        0.000                      0.000
# 25%                        0.000                      0.000
# 50%                        0.000                      0.000
# 75%                        0.000                      0.000
# max                        1.000                      1.000
#
#        cat__employment_status_CF  cat__employment_status_CG  \
# count                1000000.000                1000000.000
# mean                       0.045                      0.000
# std                        0.207                      0.022
# min                        0.000                      0.000
# 25%                        0.000                      0.000
# 50%                        0.000                      0.000
# 75%                        0.000                      0.000
# max                        1.000                      1.000
#
#        cat__housing_status_BA  cat__housing_status_BB  cat__housing_status_BC  \
# count             1000000.000             1000000.000             1000000.000
# mean                    0.215                   0.295                   0.340
# std                     0.411                   0.456                   0.474
# min                     0.000                   0.000                   0.000
# 25%                     0.000                   0.000                   0.000
# 50%                     0.000                   0.000                   0.000
# 75%                     0.000                   1.000                   1.000
# max                     1.000                   1.000                   1.000
#
#        cat__housing_status_BD  cat__housing_status_BE  cat__housing_status_BF  \
# count             1000000.000             1000000.000             1000000.000
# mean                    0.026                   0.122                   0.002
# std                     0.160                   0.327                   0.041
# min                     0.000                   0.000                   0.000
# 25%                     0.000                   0.000                   0.000
# 50%                     0.000                   0.000                   0.000
# 75%                     0.000                   0.000                   0.000
# max                     1.000                   1.000                   1.000
#
#        cat__housing_status_BG  cat__source_INTERNET  cat__source_TELEAPP  \
# count             1000000.000           1000000.000          1000000.000
# mean                    0.000                 0.992                0.008
# std                     0.017                 0.088                0.088
# min                     0.000                 0.000                0.000
# 25%                     0.000                 1.000                0.000
# 50%                     0.000                 1.000                0.000
# 75%                     0.000                 1.000                0.000
# max                     1.000                 1.000                1.000
#
#        cat__device_os_linux  cat__device_os_macintosh  cat__device_os_other  \
# count           1000000.000               1000000.000           1000000.000
# mean                  0.339                     0.049                 0.300
# std                   0.473                     0.216                 0.458
# min                   0.000                     0.000                 0.000
# 25%                   0.000                     0.000                 0.000
# 50%                   0.000                     0.000                 0.000
# 75%                   1.000                     0.000                 1.000
# max                   1.000                     1.000                 1.000
#
#        cat__device_os_windows  cat__device_os_x11
# count             1000000.000         1000000.000
# mean                    0.304               0.008
# std                     0.460               0.090
# min                     0.000               0.000
# 25%                     0.000               0.000
# 50%                     0.000               0.000
# 75%                     1.000               0.000
# max                     1.000               1.000

# %%
X_scaled_full_df.columns
# Out:
# Index(['num__fraud_bool', 'num__income', 'num__name_email_similarity',
#        'num__prev_address_months_count', 'num__current_address_months_count',
#        'num__customer_age', 'num__days_since_request',
#        'num__intended_balcon_amount', 'num__zip_count_4w', 'num__velocity_6h',
#        'num__velocity_24h', 'num__velocity_4w', 'num__bank_branch_count_8w',
#        'num__date_of_birth_distinct_emails_4w', 'num__credit_risk_score',
#        'num__email_is_free', 'num__phone_home_valid',
#        'num__phone_mobile_valid', 'num__bank_months_count',
#        'num__has_other_cards', 'num__proposed_credit_limit',
#        'num__foreign_request', 'num__session_length_in_minutes',
#        'num__keep_alive_session', 'num__device_distinct_emails_8w',
#        'num__device_fraud_count', 'num__month_sin', 'num__month_cos',
#        'cat__payment_type_AA', 'cat__payment_type_AB', 'cat__payment_type_AC',
#        'cat__payment_type_AD', 'cat__payment_type_AE',
#        'cat__employment_status_CA', 'cat__employment_status_CB',
#        'cat__employment_status_CC', 'cat__employment_status_CD',
#        'cat__employment_status_CE', 'cat__employment_status_CF',
#        'cat__employment_status_CG', 'cat__housing_status_BA',
#        'cat__housing_status_BB', 'cat__housing_status_BC',
#        'cat__housing_status_BD', 'cat__housing_status_BE',
#        'cat__housing_status_BF', 'cat__housing_status_BG',
#        'cat__source_INTERNET', 'cat__source_TELEAPP', 'cat__device_os_linux',
#        'cat__device_os_macintosh', 'cat__device_os_other',
#        'cat__device_os_windows', 'cat__device_os_x11'],
#       dtype='object')

# %%
df.shape
# Out:
# (1000000, 34)

# %%
features.shape
# Out:
# (1000000, 33)

# %%
X_scaled.shape
# Out:
# (1000000, 53)

# %%
X_scaled_full.shape
# Out:
# (1000000, 54)

# %%
save_path = "/content/drive/MyDrive/Professional/Portfolio/Fraud Detection/Data/Preprocessed/Variant II/X_scaled_full.csv"
X_scaled_full_df.to_csv(save_path, index=False)

# %%
import pickle

save_path = "/content/drive/MyDrive/Professional/Portfolio/Fraud Detection/Data/Preprocessed/Variant II/X_scaled_full.pkl"
with open(save_path, 'wb') as file:
    pickle.dump(X_scaled, file)
